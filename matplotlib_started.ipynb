# %%
import matplotlib.pyplot as plt
import matplotlib.image as mpimg

# %%
img = mpimg.imread("/content/stinkbug.webp")
print(img)
# Out:
# [[[104 104 104]
#   [104 104 104]
#   [104 104 104]
#   ...
#   [109 109 109]
#   [109 109 109]
#   [109 109 109]]
#
#  [[105 105 105]
#   [105 105 105]
#   [105 105 105]
#   ...
#   [109 109 109]
#   [109 109 109]
#   [109 109 109]]
#
#  [[107 107 107]
#   [106 106 106]
#   [106 106 106]
#   ...
#   [110 110 110]
#   [110 110 110]
#   [110 110 110]]
#
#  ...
#
#  [[112 112 112]
#   [111 111 111]
#   [110 110 110]
#   ...
#   [116 116 116]
#   [115 115 115]
#   [115 115 115]]
#
#  [[113 113 113]
#   [113 113 113]
#   [112 112 112]
#   ...
#   [115 115 115]
#   [114 114 114]
#   [114 114 114]]
#
#  [[113 113 113]
#   [115 115 115]
#   [115 115 115]
#   ...
#   [114 114 114]
#   [114 114 114]
#   [113 113 113]]]

# %%
image = plt.imshow(img)

# %%
imageg = img[:,:,0]
plt.imshow(imageg)

# %%
plt.imshow(imageg, cmap='hot')

# %%
plt.imshow(imageg, cmap='nipy_spectral')
plt.colorbar()

# %%
plt.hist(imageg.ravel(), bins=256, range=(0.0, 400.0), fc='k', ec='k')
# Out:
# (array([4.0000e+00, 6.0000e+00, 2.0000e+00, 5.0000e+00, 1.0000e+00,
#         1.6000e+01, 7.0000e+00, 9.0000e+00, 2.1000e+01, 1.5000e+01,
#         4.1000e+01, 2.1000e+01, 3.8000e+01, 3.1000e+01, 5.7000e+01,
#         2.4000e+01, 6.4000e+01, 7.8000e+01, 3.9000e+01, 1.0300e+02,
#         8.4000e+01, 1.6500e+02, 8.0000e+01, 2.1900e+02, 2.0200e+02,
#         1.1600e+02, 2.3600e+02, 1.3500e+02, 2.2900e+02, 1.2300e+02,
#         2.3400e+02, 1.1600e+02, 2.1800e+02, 2.0100e+02, 9.0000e+01,
#         2.3200e+02, 1.0400e+02, 2.1800e+02, 1.3800e+02, 2.3400e+02,
#         2.6100e+02, 1.3200e+02, 2.5500e+02, 1.3300e+02, 2.2600e+02,
#         1.1700e+02, 2.4800e+02, 1.2100e+02, 2.2600e+02, 2.1500e+02,
#         9.7000e+01, 2.2100e+02, 1.1700e+02, 1.9400e+02, 9.8000e+01,
#         2.1600e+02, 2.2900e+02, 1.2400e+02, 2.5400e+02, 1.4100e+02,
#         2.8800e+02, 1.6100e+02, 3.0000e+02, 1.5700e+02, 2.8200e+02,
#         3.4000e+02, 1.8200e+02, 3.9500e+02, 2.0600e+02, 4.6200e+02,
# ...

# %%
imgplot = plt.imshow(imageg, clim=(0.0, 190))

# %%
fig = plt.figure()
ax = fig.add_subplot(1,2,1)
imageplot = plt.imshow(imageg)
ax.set_title('Before')
plt.colorbar(ticks = [50, 100, 150, 200], orientation='horizontal')
ax = fig.add_subplot(1,2,2)
imageplot = plt.imshow(imageg)
imageplot.set_clim(25.0, 170.0)
ax.set_title('After')
plt.colorbar(ticks = [50, 100, 150, 200], orientation='horizontal')

# %%
from PIL import Image

img = Image.open('/content/stinkbug.webp')
img.thumbnail((32, 32), Image.ANTIALIAS)  # resizes image in-place
imgplot = plt.imshow(img)

# %%
imgplot = plt.imshow(img, interpolation="bicubic")

# %% [markdown]
# ##### Pyplot tutorial

# %%
import matplotlib.pyplot as plt

# %%
plt.plot([1,2,3,4])
plt.ylabel("some numbers")
plt.show
# Out:
# <function matplotlib.pyplot.show>

# %%
plt.plot([1,2,3,4], [1,4,9,16])

# %%
plt.plot([1,2,3,4], [1,4,9,16], 'ro')
plt.axis([0,6,0,20])
plt.show()

# %%
import numpy as np

t = np.arange(0, 5, 0.2)
plt.plot(t,t,'r--', t,t**2,'bs', t, t**3, 'g^')
plt.show()

# %%
np.random.randn(50)
# Out:
# array([ 0.31033539,  1.14883012,  1.68427411, -0.37500122,  0.20405302,
#        -3.85032715,  1.63955802, -0.4407802 ,  0.09997106,  0.14162426,
#         2.35488298,  0.76207594,  1.35818692,  0.73415082, -0.6309227 ,
#        -0.70393879,  0.21382606, -1.91541268, -1.78756982, -2.4052839 ,
#        -1.41258228,  0.38211058, -0.56753334, -0.3220922 ,  2.42995613,
#        -0.75203138, -0.05488733, -1.2133571 , -2.00058472,  0.78458008,
#        -0.12997937,  0.84411556, -0.29163379, -0.67246298,  2.09874446,
#        -1.44261422,  0.8021601 ,  0.52392715, -0.57896817,  0.23228748,
#        -0.58506144,  0.20771201, -1.510041  ,  0.17726762, -1.21169127,
#        -0.28150904,  0.21680301,  1.40108911, -1.21287667,  0.28984008])

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100
data['d']
# Out:
# array([159.64215702,  54.56977287,  36.12228821, 222.77812565,
#         10.40446293,  68.37997563,  72.85278949,  50.60053632,
#        101.64201079,   6.22235469,  28.40440685,  74.19834308,
#         85.76768216,  62.0771749 ,  73.68933563,  10.26833207,
#         87.40029873, 119.50065149,  35.7570015 ,  14.43393668,
#         29.54093269, 147.09071743, 103.63805631,   5.47311293,
#         40.68471752,  15.45184953,  79.95573357, 143.55510615,
#        126.53046615,   7.24195843, 192.60685275,  97.15523417,
#        130.94881434,  87.6935894 ,   6.84257657,  56.38583293,
#        156.49041844, 150.96308593,   7.21844543,  32.21350349,
#         32.6638863 , 107.95921396,  23.77721147,  21.05081552,
#          1.67130389, 166.05153743,  13.59475223,  65.60332687,
#        197.82059185,  49.27498018])

# %%
data = {'a': np.arange(50),
        'c': np.random.randint(0, 50, 50),
        'd': np.random.randn(50)}
data['b'] = data['a'] + 10 * np.random.randn(50)
data['d'] = np.abs(data['d']) * 100

plt.scatter('a', 'b', c='c', s='d', data=data)
plt.xlabel('entry a')
plt.ylabel('entry b')
plt.show()

# %%
names = ['group_a', 'group_b', 'group_c']
values = [1, 10, 100]

plt.figure(figsize=(9, 3))

plt.subplot(1,3,1)
plt.bar(names, values)
plt.subplot(132)
plt.scatter(names, values)
plt.subplot(133)
plt.plot(names, values)
plt.suptitle('Categorical Plotting')
plt.show()

# %%
x = np.random.randint(0,10,7)
y = np.random.randint(0,10,7)
line, = plt.plot(x, y, '-')

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
mu, sigma = 100, 15
x = mu + sigma * np.random.randn(10000)

# the histogram of the data
n, bins, patches = plt.hist(x, 50, density=1, facecolor='g', alpha=0.75)


plt.xlabel('Smarts')
plt.ylabel('Probability')
plt.title('Histogram of IQ')
plt.text(60, .025, r'$\mu=100,\ \sigma=15$')
plt.axis([40, 160, 0, 0.03])
plt.grid(True)
plt.show()

# %%
ax = plt.subplot(111)

t = np.arange(0.0, 5.0, 0.01)
s = np.cos(2*np.pi*t)
line, = plt.plot(t, s, lw=2)

plt.annotate('local max', xy=(2, 1), xytext=(3, 1.5),
             arrowprops=dict(facecolor='black', shrink=0.05),
             )

plt.ylim(-2, 2)
plt.show()
